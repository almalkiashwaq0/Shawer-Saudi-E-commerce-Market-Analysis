# %%
import pandas as pd 
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('stores.csv')

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
df
# Out:
#                               Name                                   NameAr  \
# 0                      qasralawani                              قصر الأواني
# 1    Uninted Homeware Company Nice  الشركة المتحدة للمستلزمات المنزلية نايس
# 2                      Marwa Store                                متجر مروه
# 3                        mdesign97          تصميم دعوات الكترونية للمناسبات
# 4                Muteb VIP Numbers                     متعب للأرقام المميزة
# ..                             ...                                      ...
# 208                      flam rare            مؤسسة الشعلة النادرة التجارية
# 209                    DAIEM STORE                               متجر داعم1
# 210                    Hekayt noon                                حكاية نون
# 211                       FitNeeds                         احتياجات اللياقة
# 212                   Tuliip Store                              متجر تولييب
#
# ...

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-09-04 19:46:13.735898&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.isna
# Out:
# <bound method DataFrame.isna of                               Name                                   NameAr  \
# 0                      qasralawani                              قصر الأواني
# 1    Uninted Homeware Company Nice  الشركة المتحدة للمستلزمات المنزلية نايس
# 2                      Marwa Store                                متجر مروه
# 3                        mdesign97          تصميم دعوات الكترونية للمناسبات
# 4                Muteb VIP Numbers                     متعب للأرقام المميزة
# ..                             ...                                      ...
# 208                      flam rare            مؤسسة الشعلة النادرة التجارية
# 209                    DAIEM STORE                               متجر داعم1
# 210                    Hekayt noon                                حكاية نون
# 211                       FitNeeds                         احتياجات اللياقة
# 212                   Tuliip Store                              متجر تولييب
#
# ...

# %%
df
# Out:
#                               Name                                   NameAr  \
# 0                      qasralawani                              قصر الأواني
# 1    Uninted Homeware Company Nice  الشركة المتحدة للمستلزمات المنزلية نايس
# 2                      Marwa Store                                متجر مروه
# 3                        mdesign97          تصميم دعوات الكترونية للمناسبات
# 4                Muteb VIP Numbers                     متعب للأرقام المميزة
# ..                             ...                                      ...
# 208                      flam rare            مؤسسة الشعلة النادرة التجارية
# 209                    DAIEM STORE                               متجر داعم1
# 210                    Hekayt noon                                حكاية نون
# 211                       FitNeeds                         احتياجات اللياقة
# 212                   Tuliip Store                              متجر تولييب
#
# ...

# %%
count_dash = (df == '-').sum().sum()

print(count_dash)
# Out:
# 0

# %%
count_slash = (df == '/').sum().sum()

print(count_slash)
# Out:
# 0

# %%
df.dtypes
# Out:
# Name                    object
# NameAr                  object
# LocalizedName           object
# BusinessType            object
# OtherTypeName           object
# IsPopularBusiness         bool
# TotalReviews             int64
# Rating                 float64
# Id                       int64
# ActiveStatus             int64
# OwnerAllowStatus         int64
# CertificationStatus      int64
# dtype: object

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                                                   Name  \
# 0                                          qasralawani
# 1                        Uninted Homeware Company Nice
# 2                                          Marwa Store
# 3                                            mdesign97
# 4                                    Muteb VIP Numbers
# 5                            ahmad audio systems store
# 6                                            Shoptouch
# 7                               Enjaz Services Company
# 8                                                  NaN
# 9                                         Mahas Jewels
# 10                                         Squad Games
# 11                                      Rawanta Online
# 12                                        Loud Crative
# 13                                         via flowerd
# 14                                         LS STICKERS
# 15                                        gifts sharif
# ...

# %%
nan_name = df[df['Name'].isna()]
nan_name
# Out:
#     Name                         NameAr                  LocalizedName  \
# 8    NaN                 سما وسيطة تسوق                 سما وسيطة تسوق
# 17   NaN                      متجر بياض                      متجر بياض
# 43   NaN                منصة اسأل محامي                منصة اسأل محامي
# 67   NaN                           كورد                           كورد
# 87   NaN  مركزلمسة رنيم للتزيين النسائي  مركزلمسة رنيم للتزيين النسائي
# 174  NaN                       كشف ستور                       كشف ستور
# 207  NaN               متجر أرقام مميزة               متجر أرقام مميزة
#
#       BusinessType OtherTypeName  IsPopularBusiness  TotalReviews  Rating  \
# 8    خدمات الأعمال           NaN              False            53    5.00
# 17           هدايا           NaN              False            88    4.95
# 43   خدمات الأعمال           NaN              False           623    4.92
# 67           حفلات           NaN              False            98    4.89
# ...

# %%
df.loc[df['Id'] == 192491, 'Name'] = 'SAMA shopping mall'
df.loc[df['Id'] == 229217, 'Name'] = 'Bayadh Store'
df.loc[df['Id'] == 258697, 'Name'] = 'asal muhami Platform'
df.loc[df['Id'] == 141238, 'Name'] = 'Kord'
df.loc[df['Id'] == 24974, 'Name'] = 'lamsa Center'
df.loc[df['Id'] == 79508, 'Name'] = 'kashf Store'
df.loc[df['Id'] == 179067, 'Name'] = 'arqam mumayaza Store'

# %%
df
# Out:
#                                                   Name  \
# 0                                          qasralawani
# 1                        Uninted Homeware Company Nice
# 2                                          Marwa Store
# 3                                            mdesign97
# 4                                    Muteb VIP Numbers
# 5                            ahmad audio systems store
# 6                                            Shoptouch
# 7                               Enjaz Services Company
# 8                                   SAMA shopping mall
# 9                                         Mahas Jewels
# 10                                         Squad Games
# 11                                      Rawanta Online
# 12                                        Loud Crative
# 13                                         via flowerd
# 14                                         LS STICKERS
# 15                                        gifts sharif
# ...

# %%
df.loc[df['Id'] == 78646, 'BusinessType'] = 'وكالة سفر'
df.loc[df['Id'] == 94622, 'BusinessType'] = 'متجر تجميعات واجهزة مكتبية وطابعات وشاشات ولاب'
df.loc[df['Id'] == 141006, 'BusinessType'] = 'تسوق وتوصيل'
df.loc[df['Id'] == 53608, 'BusinessType'] = 'خدمات دراسات الجدوي والاستشارات الاقتصادية'
df.loc[df['Id'] == 301325, 'BusinessType'] = 'أزياء'
df.loc[df['Id'] == 321044, 'BusinessType'] = 'أزياء'

# %%
df
# Out:
#                                                   Name  \
# 0                                          qasralawani
# 1                        Uninted Homeware Company Nice
# 2                                          Marwa Store
# 3                                            mdesign97
# 4                                    Muteb VIP Numbers
# 5                            ahmad audio systems store
# 6                                            Shoptouch
# 7                               Enjaz Services Company
# 8                                   SAMA shopping mall
# 9                                         Mahas Jewels
# 10                                         Squad Games
# 11                                      Rawanta Online
# 12                                        Loud Crative
# 13                                         via flowerd
# 14                                         LS STICKERS
# 15                                        gifts sharif
# ...

# %%
df = df.drop(columns=["OtherTypeName"])

# %%
df.to_csv('cleaned_data_Allstores.csv')
from IPython.display import FileLink
FileLink("cleaned_data_Allstores.csv")
# Out:
# c:\Users\LENOVO\Downloads\cleaned_data_Allstores.csv
